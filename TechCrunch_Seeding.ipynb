# %%
import requests
import psycopg2
from bs4 import BeautifulSoup
from langchain_postgres import PGVector
from langchain_openai import OpenAIEmbeddings
import os
from dotenv import load_dotenv
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_core.documents import Document
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate

load_dotenv()
# Out:
# True

# %%
def get_articles_from_url(url):
    page = requests.get(url)
    soup = BeautifulSoup(page.content, "html.parser")

    check404 = soup.find("body", class_="error404")
    if check404:
        return None
    
    articles_bulk = soup.find_all("ul", class_="wp-block-post-template")
    articles = articles_bulk[0].find_all("a", class_="loop-card__title-link")

    return [(article.text.strip(), article["href"]) for article in articles]

def get_article_content(url):
    page = requests.get(url)
    soup = BeautifulSoup(page.content, "html.parser")

    check404 = soup.find("body", class_="error404")
    isLive = soup.find("span", class_="wp-block-techcrunch-storyline-hero__live")
    year = url.split("/")[3]

    if check404 or isLive or year != "2025":
        return None

    
    try: 
        title = soup.find("h1", class_="article-hero__title")
        if title is None:
            title = soup.find("h1", class_="wp-block-post-title").text.strip()
        else:
            title = title.text.strip()
                
        author = soup.find("a", class_="wp-block-tc23-author-card-name__link")
        if author is None:
            author = soup.find("a", class_="post-authors-list__author")
            if author is None:
                author = "anonymous"
            else: 
                author = author.text.strip()
        else:
            author = author.text.strip()
        author = author.replace("'", "’")

        time_div = soup.find("div", class_="wp-block-post-date")
        time = time_div.find("time").text.strip()

            
        image = soup.find("img", class_="attachment-post-thumbnail")["src"]
        
        category = soup.find("a", class_="is-taxonomy-category")

        if category is None:
            category = soup.find("span", class_="wp-block-tenup-post-primary-term").text.strip()
        else:
            category = category.text.strip()
        
        text_body = soup.find("div", class_="entry-content")
        text_paragraphs_and_titles = text_body.find_all(["p", "h2"])
        text = "\n".join([p.text.strip() for p in text_paragraphs_and_titles])
        text = f"{title}\n{text}"

    except:
        raise Exception("Error parsing article content for url", url)
        
    return {"title": title, "author": author, "time": time, "image": image, "category": category, "url": url}, text


def summarize_content(text, llm, idx, url):
    prompt = PromptTemplate.from_template("""Summarize the following news article in up to 4 sentences, building intrigue and interest. Do not include or rephrase the title in the summary, assuming that the audience has already read it. Do not ask questions in the summary. Make the summary comprehensive, but presented in simple terms, in such a way that invites the reader to ask you questions to find out the details. After that, provide a list of 3 questions that the reader can ask you to find out more details and clarifications.

Article: "{article}"

Answer exactly as in the following format:

Summary: 

Question 1:

Question 2:

Question 3:""")
    prompt = prompt.format(article=text)
    
    retries = 2
    for attempt in range(retries + 1):
        answer = llm.invoke(prompt)
        answer = answer.content.replace("'", "’")
        
        components = answer.split('\n')
        if len(components) >= 7:
            summary = components[0][9:]
            q1 = components[2][12:].strip()
            q2 = components[4][12:].strip()
            q3 = components[6][12:].strip()
            questions = "&&&".join([q1, q2, q3])
            return summary, questions
        elif attempt < retries:
            continue
        else:
            raise ValueError(f"Unexpected response format from language model: idx in total_articles {idx}, url {url}")

# %%
def insert_article_to_sql(cursor, metadata, llm, idx, text):
    cursor.execute(f"""select * from article where link = '{metadata["url"]}'""")
    if cursor.fetchone():
        print(f"{idx} - Article already exists in database: {metadata['url']}")
        return
    
    summary, questions = summarize_content(text, llm, idx, metadata["url"])

    cursor.execute(f"""insert into article VALUES(
        '{metadata["url"]}', '{metadata["title"]}', '{metadata["author"]}', '{metadata["time"]}', '{metadata["image"]}','{metadata["category"]}',
        '{summary}', '{questions}')""")
    cursor.execute("commit")
    print(f"{idx} - Inserted article {metadata['title']} into database")
    return

# %%
#TODO: change metadata time to date and remove metadata image

def insert_all_articles(total_articles, cursor, llm, vectorstore, text_splitter):
    all_docs = []

    for idx, article in enumerate(total_articles):
        result = get_article_content(article[1])
        if result is None:
            print(f"{idx} - Article not found or not supported: {article[1]}")
            continue
        article_data, text = result
    
        insert_article_to_sql(cursor, article_data, llm, idx, text)
        
        article_doc = Document(page_content=text, metadata=article_data)
        all_docs.append(article_doc)
    
    splits = text_splitter.split_documents(all_docs)

    _ = vectorstore.add_documents(documents=splits)
    print("All articles inserted into database")
    
    return

# %%
total_articles = []
URL = "https://techcrunch.com/2025/"

total_articles.extend(get_articles_from_url(URL))

for i in range(2, 1000):
    URL = f"https://techcrunch.com/2025/page/{i}"
    articles = get_articles_from_url(URL)
    if not articles:
        break
    total_articles.extend(articles)

print(len(total_articles))
# Out:
# 298

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,  # chunk size (characters)
    chunk_overlap=200,  # chunk overlap (characters)
    add_start_index=True,  # track index in original document
)
#all_splits = text_splitter.split_documents(docs)

#print(f"Split blog post into {len(all_splits)} sub-documents.")

# %%
embeddings = OpenAIEmbeddings(model="text-embedding-3-large")
vector_store = PGVector(
    embeddings=embeddings,
    collection_name="my_docs",
    connection="postgresql+psycopg://stefan:gigelfrone112@localhost:5432/techvector",
)

# %%
llm = ChatOpenAI(model="gpt-4o-mini")
conn = psycopg2.connect("dbname=techvector user=stefan password=gigelfrone112 host=localhost port=5432")
cursor = conn.cursor()

# %%
insert_all_articles(total_articles, cursor, llm, vector_store, text_splitter)
# Out:
# 0 - Article already exists in database: https://techcrunch.com/2025/01/11/apple-board-opposes-proposal-to-abolish-dei-programs/
# 1 - Article already exists in database: https://techcrunch.com/2025/01/11/researchers-open-source-sky-t1-a-reasoning-ai-model-that-can-be-trained-for-less-than-450/
# 2 - Article already exists in database: https://techcrunch.com/2025/01/11/whats-behind-ballooning-video-game-budgets/
# 3 - Article already exists in database: https://techcrunch.com/2025/01/11/everything-you-missed-at-ces-2025/
# 4 - Article already exists in database: https://techcrunch.com/2025/01/11/i-got-soaked-driving-the-arc-sport-electric-boat/
# 5 - Article already exists in database: https://techcrunch.com/2025/01/11/matt-mullenweg-deactivates-wordpress-accounts-of-contributors-planning-a-fork/
# 6 - Article already exists in database: https://techcrunch.com/2025/01/11/nvidias-ai-empire-a-look-at-its-top-startup-investments/
# 7 - Article already exists in database: https://techcrunch.com/2025/01/10/snappy-aquires-swag-gifting-startup-covver-as-it-seks-to-roll-up-players/
# 8 - Article already exists in database: https://techcrunch.com/2025/01/10/microsoft-accuses-group-of-developing-tool-to-abuse-its-ai-service-in-new-lawsuit/
# 9 - Article already exists in database: https://techcrunch.com/2025/01/10/mark-zuckerberg-defends-metas-latest-pivot-in-three-hour-joe-rogan-interview/
# 10 - Article already exists in database: https://techcrunch.com/2025/01/10/these-startups-are-making-smarter-canes-for-people-with-visual-impairments/
# 11 - Article already exists in database: https://techcrunch.com/2025/01/10/a-drone-punched-a-hole-into-an-la-firefighting-plane/
# 12 - Article already exists in database: https://techcrunch.com/2025/01/10/bench-customers-are-now-being-forced-to-hand-over-their-data-or-risk-losing-it-they-say/
# 13 - Article already exists in database: https://techcrunch.com/2025/01/10/amazon-curbs-some-dei-programs/
# 14 - Article already exists in database: https://techcrunch.com/2025/01/10/tiktok-ban-how-both-sides-made-their-case-to-the-supreme-court-and-what-the-justices-asked/
# 15 - Article already exists in database: https://techcrunch.com/2025/01/10/new-openai-job-listings-reveal-its-robotics-plans/
# 16 - Article already exists in database: https://techcrunch.com/2025/01/10/how-openais-bot-crushed-this-seven-person-companys-web-site-like-a-ddos-attack/
# 17 - Article already exists in database: https://techcrunch.com/2025/01/10/vcs-say-ai-companies-need-proprietary-data-to-stand-out-from-the-pack/
# 18 - Article already exists in database: https://techcrunch.com/2025/01/10/lenovos-latest-form-factors-prove-pcs-can-still-be-fun/
# 19 - Article already exists in database: https://techcrunch.com/2025/01/10/how-to-delete-facebook-instagram-and-threads/
# 20 - Article already exists in database: https://techcrunch.com/2025/01/10/riding-in-a-zoox-robotaxi-at-ces-2025-everything-that-went-right-and-wrong/
# 21 - Article already exists in database: https://techcrunch.com/2025/01/10/hugging-face-settles-suit-with-ai-startup-friendliai-which-had-accused-it-of-patent-infringement/
# 22 - Article already exists in database: https://techcrunch.com/2025/01/10/meet-the-chinese-typhoon-hackers-preparing-for-war/
# 23 - Article already exists in database: https://techcrunch.com/2025/01/10/shein-is-still-looking-to-ipo/
# 24 - Article already exists in database: https://techcrunch.com/2025/01/10/meta-eliminates-dei-programs/
# 25 - Article already exists in database: https://techcrunch.com/2025/01/10/january-almost-had-its-first-pentacorn-and-other-startup-news/
# 26 - Article already exists in database: https://techcrunch.com/2025/01/10/eu-approves-35b-synopsys-and-ansys-merger-subject-to-divestment-conditions/
# 27 - Article already exists in database: https://techcrunch.com/2025/01/10/overhaul-keeps-tabs-on-cargo-for-customers-like-microsoft-and-dyson/
# 28 - Article already exists in database: https://techcrunch.com/2025/01/10/the-new-atari-handheld-knows-its-market/
# 29 - Article already exists in database: https://techcrunch.com/2025/01/10/tiktok-pleads-its-case-against-sell-or-ban-law-before-supreme-court/
# 30 - Article already exists in database: https://techcrunch.com/2025/01/10/us-government-charges-operators-of-crypto-mixing-service-used-by-north-korea-and-ransomware-gangs/
# 31 - Article not found or not supported: https://techcrunch.com/podcast/5b-livestream-shopping-apps-nvidia-reveals-and-the-weirdest-tech-at-ces/
# 32 - Article already exists in database: https://techcrunch.com/2025/01/10/china-hacked-us-treasurys-cfius-which-reviews-foreign-investments-for-national-security-risks/
# 33 - Article already exists in database: https://techcrunch.com/2025/01/10/cannabis-company-stiiizy-says-hackers-accessed-customers-id-documents/
# 34 - Article already exists in database: https://techcrunch.com/2025/01/10/gumloop-founded-in-a-bedroom-in-vancouver-lets-users-automate-tasks-with-drag-and-drop-modules/
# 35 - Article not found or not supported: https://techcrunch.com/storyline/live-updates-ces-2025-the-final-reveals-and-analysis-as-the-event-nears-its-end/
# 36 - Article already exists in database: https://techcrunch.com/2025/01/10/automattic-says-it-will-reduce-its-contribution-to-wordpress-core-project-to-match-wp-engine/
# 37 - Article already exists in database: https://techcrunch.com/2025/01/09/beams-secures-9m-series-a-to-digitize-uk-home-renovation-market/
# 38 - Article already exists in database: https://techcrunch.com/2025/01/09/india-rupay-upi-payment-push-is-cutting-out-visa-and-mastercard/
# 39 - Article already exists in database: https://techcrunch.com/2025/01/09/x-says-it-is-rolling-out-labels-for-parody-accounts/
# 40 - Article already exists in database: https://techcrunch.com/2025/01/09/every-smartphone-in-la-accidentally-received-a-wildfire-evacuation-alert/
# 41 - Article already exists in database: https://techcrunch.com/2025/01/09/this-security-system-shoots-paintballs-at-intruders/
# 42 - Article already exists in database: https://techcrunch.com/2025/01/09/tesla-launches-new-look-model-y-in-china/
# 43 - Article already exists in database: https://techcrunch.com/2025/01/09/hippocratic-ai-raises-141m-for-creating-patient-facing-ai-agents/
# 44 - Article already exists in database: https://techcrunch.com/2025/01/09/nvidias-ai-avatar-sat-on-my-computer-screen-and-weirded-me-out/
# 45 - Article already exists in database: https://techcrunch.com/2025/01/09/icon-a-builder-of-3d-printed-homes-last-valued-around-2-billion-cuts-about-25-of-staff/
# 46 - Article already exists in database: https://techcrunch.com/2025/01/09/defense-startup-epirus-in-talks-to-raise-over-150m-potentially-cutting-valuation/
# 47 - Article already exists in database: https://techcrunch.com/2025/01/09/apptroniks-apollo-humanoid-robot-gets-to-work-at-ces-2025/
# 48 - Article already exists in database: https://techcrunch.com/2025/01/09/tiktok-tells-la-staff-impacted-by-wildfires-to-use-personal-sick-hours-if-they-cant-work-from-home/
# 49 - Article already exists in database: https://techcrunch.com/2025/01/09/chatgpts-newest-feature-lets-user-assign-it-traits-like-chatty-and-gen-z/
# 50 - Article already exists in database: https://techcrunch.com/2025/01/09/autonomous-vehicles-are-having-a-moment-and-other-vibes-from-ces-2025/
# 51 - Article already exists in database: https://techcrunch.com/2025/01/09/ces-2025-where-have-all-the-us-automakers-gone/
# 52 - Article already exists in database: https://techcrunch.com/2025/01/09/google-folds-more-ai-teams-into-deepmind-to-accelerate-the-research-to-developer-pipeline/
# 53 - Article already exists in database: https://techcrunch.com/2025/01/09/scale-ai-hit-by-its-second-employee-wage-lawsuit-in-less-than-a-month/
# 54 - Article already exists in database: https://techcrunch.com/2025/01/09/y-combinator-scored-a-surprise-win-when-larry-page-came-to-speak/
# 55 - Article already exists in database: https://techcrunch.com/2025/01/09/these-are-ces-2025s-least-repairable-and-sustainable-gadgets-according-to-ifixit/
# 56 - Article already exists in database: https://techcrunch.com/2025/01/09/doorbox-debuts-its-new-and-improved-smart-delivery-box-at-ces-2025/
# 57 - Article already exists in database: https://techcrunch.com/2025/01/09/mark-zuckerberg-gave-metas-llama-team-the-ok-to-train-on-copyrighted-works-filing-claims/
# 58 - Article already exists in database: https://techcrunch.com/2025/01/09/facebook-awards-researcher-100000-for-finding-bug-that-granted-internal-access/
# 59 - Article already exists in database: https://techcrunch.com/2025/01/09/scout-motors-ceo-scott-keogh-interview-ces-2025/
# 60 - Article already exists in database: https://techcrunch.com/2025/01/09/ces-2025-the-weirdest-tech-products-and-claims-from-this-years-event/
# 61 - Article already exists in database: https://techcrunch.com/2025/01/09/comcast-and-other-tv-streamers-are-now-chasing-youtubes-ad-dollars-instead-of-the-other-way-around/
# 62 - Article already exists in database: https://techcrunch.com/2025/01/09/google-searches-for-deleting-facebook-instagram-explode-after-meta-ends-fact-checking/
# 63 - Article already exists in database: https://techcrunch.com/2025/01/09/watch-duty-surpasses-chatgpt-as-top-free-app-on-app-store-as-california-fires-spread/
# 64 - Article already exists in database: https://techcrunch.com/2025/01/09/powerschool-says-hackers-stole-students-sensitive-data-including-social-security-numbers-in-data-breach/
# 65 - Article already exists in database: https://techcrunch.com/2025/01/09/googles-daily-listen-ai-feature-generates-a-podcast-based-on-your-discover-feed/
# 66 - Article already exists in database: https://techcrunch.com/2025/01/09/doublepoint-launches-free-apple-watch-app-to-control-devices-with-hand-gestures/
# 67 - Article already exists in database: https://techcrunch.com/2025/01/09/video-editing-app-captions-switches-to-a-freemium-model-to-boost-growth/
# 68 - Article already exists in database: https://techcrunch.com/2025/01/09/prettydamnquick-snaps-up-25m-to-speed-up-online-checkout/
# 69 - Article already exists in database: https://techcrunch.com/2025/01/09/innovaccer-aims-to-become-healthcares-ai-powerhouse-with-275m-series-f/
# 70 - Article already exists in database: https://techcrunch.com/2025/01/09/tesla-directors-to-pay-up-to-919-million-to-settle-claims-they-overpaid-themselves/
# 71 - Article already exists in database: https://techcrunch.com/2025/01/09/rounded-is-an-ai-orchestration-platform-that-lets-anyone-build-an-ai-voice-agent/
# 72 - Article already exists in database: https://techcrunch.com/2025/01/09/biosphere-zaps-germs-with-uv-light-to-make-biomanufacturing-cheaper/
# 73 - Article already exists in database: https://techcrunch.com/2025/01/09/hackers-are-exploiting-a-new-ivanti-vpn-security-bug-to-hack-into-company-networks/
# 74 - Article already exists in database: https://techcrunch.com/2025/01/09/xocean-raises-119m-to-capture-ocean-data-with-uncrewed-surface-vessels/
# 75 - Article already exists in database: https://techcrunch.com/2025/01/09/vlc-tops-6-billion-downloads-previews-ai-generated-subtitles/
# 76 - Article already exists in database: https://techcrunch.com/2025/01/09/apple-might-be-working-on-a-new-invites-app/
# 77 - Article already exists in database: https://techcrunch.com/2025/01/09/grand-games-the-turkish-gaming-startup-behind-pouring-game-magic-sort-drinks-up-30m/
# 78 - Article already exists in database: https://techcrunch.com/2025/01/09/defiant-is-a-new-european-vc-firm-that-uses-data-and-products-to-make-better-investments/
# 79 - Article already exists in database: https://techcrunch.com/2025/01/08/xai-is-testing-a-standalone-ios-app-for-its-grok-chatbot/
# 80 - Article already exists in database: https://techcrunch.com/2025/01/08/flipkart-taps-dunzo-founder-to-lead-quick-commerce-push/
# 81 - Article already exists in database: https://techcrunch.com/2025/01/08/elon-musk-agrees-that-weve-exhausted-ai-training-data/
# 82 - Article already exists in database: https://techcrunch.com/2025/01/08/we-talked-to-the-guy-who-was-stuck-in-a-waymo-robotaxi-on-an-dizzying-loop/
# 83 - Article already exists in database: https://techcrunch.com/2025/01/08/the-u-s-has-a-new-cybersecurity-safety-label-for-smart-devices/
# 84 - Article already exists in database: https://techcrunch.com/2025/01/08/the-liberlive-c1-stringless-instrument-isnt-a-guitar-and-thats-fine/
# 85 - Article already exists in database: https://techcrunch.com/2025/01/08/ces-2025-was-full-of-irl-ai-slop/
# 86 - Article already exists in database: https://techcrunch.com/2025/01/08/pickpad-addresses-the-chaos-of-restaurant-takeout/
# 87 - Article already exists in database: https://techcrunch.com/2025/01/08/astrohaus-launches-a-mechanical-keyboard-for-writers/
# 88 - Article already exists in database: https://techcrunch.com/2025/01/08/grok-may-soon-get-an-unhinged-mode/
# 89 - Article already exists in database: https://techcrunch.com/2025/01/08/hallidays-489-smart-glasses-beam-a-tiny-screen-to-your-eye/
# 90 - Article already exists in database: https://techcrunch.com/2025/01/08/this-1500-ipad-bundle-will-rickroll-your-family-after-you-die/
# 91 - Article already exists in database: https://techcrunch.com/2025/01/08/flock-safety-quietly-hired-a-sitting-california-mayor-now-hes-suing-flock/
# 92 - Article already exists in database: https://techcrunch.com/2025/01/08/ai-researcher-francois-chollet-is-co-founding-a-nonprofit-to-build-benchmarks-for-agi/
# 93 - Article already exists in database: https://techcrunch.com/2025/01/08/mastodon-ceo-calls-metas-moderation-changes-deeply-troubling-warns-users-cross-posting-from-threads/
# 94 - Article already exists in database: https://techcrunch.com/2025/01/08/gamers-cant-fathom-how-6x-ceo-elon-musk-found-time-to-best-diablo-iv/
# 95 - Article already exists in database: https://techcrunch.com/2025/01/08/this-basketball-robot-uses-ai-to-rebound-the-ball-after-you-shoot/
# 96 - Article already exists in database: https://techcrunch.com/2025/01/08/gridwares-boxes-literally-listen-to-power-lines-to-find-outages/
# 97 - Article already exists in database: https://techcrunch.com/2025/01/08/tech-layoffs-2024-list/
# 98 - Article already exists in database: https://techcrunch.com/2025/01/08/ukrainian-hackers-take-credit-for-hacking-russian-isp-that-wiped-out-servers-and-caused-internet-outages/
# 99 - Article already exists in database: https://techcrunch.com/2025/01/08/this-week-in-ai-more-capable-ai-is-coming-but-will-its-benefits-be-evenly-distributed/
# 100 - Article already exists in database: https://techcrunch.com/2025/01/08/triller-launches-a-tool-to-back-up-users-tiktoks-ahead-of-the-u-s-ban-deadline/
# 101 - Article already exists in database: https://techcrunch.com/2025/01/08/tonals-new-strength-training-system-arrives-with-refreshed-hardware-and-new-workouts/
# 102 - Article already exists in database: https://techcrunch.com/2025/01/08/boston-dynamics-settles-patent-suit-with-military-robotics-firm-ghost/
# 103 - Article already exists in database: https://techcrunch.com/2025/01/08/former-huami-employees-launch-satellai-a-satellite-pet-tracker-at-ces-2025/
# 104 - Article already exists in database: https://techcrunch.com/2025/01/08/japan-says-chinese-hackers-targeted-its-government-and-tech-companies-for-years/
# 105 - Article already exists in database: https://techcrunch.com/2025/01/08/omi-a-competitor-to-friend-wants-to-boost-your-productivity-using-ai-and-a-brain-interface/
# 106 - Article already exists in database: https://techcrunch.com/2025/01/08/grove-cuts-clinical-trial-enrollment-time-with-ai/
# 107 - Article already exists in database: https://techcrunch.com/2025/01/08/microsoft-rolls-back-its-bing-image-creator-model-after-users-complain-of-degraded-quality/
# 108 - Article already exists in database: https://techcrunch.com/2025/01/08/former-ceo-of-moviepass-parent-company-pleads-guilty-to-fraud-over-unlimited-plan/
# 109 - Article already exists in database: https://techcrunch.com/2025/01/08/facebook-marketplace-to-display-ebay-listings-to-appease-eu-regulators/
# 110 - Article already exists in database: https://techcrunch.com/2025/01/08/healthcare-analytics-platform-h1-has-acquired-ribbon-backed-by-a16z-and-general-catalyst/
# 111 - Article already exists in database: https://techcrunch.com/2025/01/08/edtech-giant-powerschool-says-hackers-accessed-personal-data-of-students-and-teachers/
# 112 - Article already exists in database: https://techcrunch.com/2025/01/08/vay-expands-driverless-car-sharing-fleet-in-las-vegas/
# 113 - Article already exists in database: https://techcrunch.com/2025/01/08/eu-court-fines-european-commission-for-breaching-its-own-data-privacy-laws/
# 114 - Article already exists in database: https://techcrunch.com/2025/01/08/livestream-shopping-app-whatnot-raises-265m-pinning-valuation-at-nearly-5b/
# 115 - Article already exists in database: https://techcrunch.com/2025/01/08/steamos-expands-to-other-gaming-handhelds-with-the-lenovo-legion-go-s/
# 116 - Article already exists in database: https://techcrunch.com/2025/01/08/casio-says-hackers-stole-personal-data-of-8500-people-during-october-ransomware-attack/
# 117 - Article already exists in database: https://techcrunch.com/2025/01/08/sirens-smart-sock-for-diabetics-secures-strategic-funding-round/
# 118 - Article already exists in database: https://techcrunch.com/2025/01/08/un-aviation-agency-confirms-hacker-breached-recruitment-database-to-access-thousands-of-records/
# 119 - Article already exists in database: https://techcrunch.com/2025/01/08/microsoft-backs-its-3b-ai-push-in-india-with-public-and-private-sector-deals/
# 120 - Article already exists in database: https://techcrunch.com/2025/01/07/nomupay-raises-37m-on-a-200m-valuation-to-build-payment-rails-in-underserved-markets-across-asia/
# 121 - Article already exists in database: https://techcrunch.com/2025/01/07/report-vc-in-emerging-markets-plummeted-by-over-40-last-year/
# 122 - Article already exists in database: https://techcrunch.com/2025/01/07/indian-government-websites-are-still-redirecting-users-to-scam-sites/
# 123 - Article already exists in database: https://techcrunch.com/2025/01/07/delta-skymiles-members-can-now-earn-miles-riding-with-uber-ending-its-deal-with-lyft/
# 124 - Article already exists in database: https://techcrunch.com/2025/01/07/sam-altmans-family-responds-to-lawsuit-alleging-he-sexually-assaulted-his-sister/
# 125 - Article already exists in database: https://techcrunch.com/2025/01/07/delta-air-lines-announces-an-ai-powered-assistant-in-its-mobile-app-and-free-onboard-youtube-premium-and-music-at-ces-2025/
# 126 - Article already exists in database: https://techcrunch.com/2025/01/07/zeekr-rt-the-robotaxi-built-for-waymo-has-the-tiniest-wipers/
# 127 - Article already exists in database: https://techcrunch.com/2025/01/07/nvidia-ceo-says-his-ai-chips-are-improving-faster-than-moores-law/
# 128 - Article already exists in database: https://techcrunch.com/2025/01/07/ces-2025-day-1-honda-bmw-xs-victory-lap-and-the-first-show-floor-gadget-reveals/
# 129 - Article already exists in database: https://techcrunch.com/2025/01/07/x-hires-former-wsj-editor-and-bureau-chief-to-lead-news-group/
# 130 - Article already exists in database: https://techcrunch.com/2025/01/07/this-pool-cleaning-company-made-a-robot-turtle-to-track-water-quality/
# 131 - Article already exists in database: https://techcrunch.com/2025/01/07/silicon-valley-is-so-dominant-again-its-startups-devoured-over-half-of-all-global-vc-funding-in-2024/
# 132 - Article already exists in database: https://techcrunch.com/2025/01/07/this-baseball-radar-gun-plugs-into-an-iphone/
# 133 - Article already exists in database: https://techcrunch.com/2025/01/07/feds-investigate-teslas-actual-smart-summon-after-several-crashes/
# 134 - Article already exists in database: https://techcrunch.com/2025/01/07/aws-says-itll-invest-at-least-11b-to-expand-data-center-infrastructure-in-georgia/
# 135 - Article already exists in database: https://techcrunch.com/2025/01/07/ftc-accuses-gig-work-app-handy-of-misleading-ads-and-opaque-fees-for-workers/
# 136 - Article already exists in database: https://techcrunch.com/2025/01/07/you-can-plug-a-second-mic-into-shures-new-mv7i/
# 137 - Article already exists in database: https://techcrunch.com/2025/01/07/nuclear-startup-deep-fission-plans-to-bury-micro-reactors-to-power-data-centers/
# 138 - Article already exists in database: https://techcrunch.com/2025/01/07/chinese-vcs-are-hounding-failed-founders-to-claw-back-their-investments/
# 139 - Article already exists in database: https://techcrunch.com/2025/01/07/threads-prototypes-custom-display-names-and-cover-images-for-profiles/
# 140 - Article already exists in database: https://techcrunch.com/2025/01/07/anthropic-reportedly-in-talks-to-raise-2b-at-60b-valuation-led-by-lightspeed/
# 141 - Article already exists in database: https://techcrunch.com/2025/01/07/xpeng-aero-ht-unveils-flying-car-thats-part-van-part-evtol-at-ces-2025/
# 142 - Article already exists in database: https://techcrunch.com/2025/01/07/south-park-commons-is-raising-40m-for-an-india-specific-fund/
# 143 - Article already exists in database: https://techcrunch.com/2025/01/07/telegram-reports-spike-in-sharing-user-data-with-law-enforcement/
# 144 - Article already exists in database: https://techcrunch.com/2025/01/07/honda-reveals-its-futuristic-0-suv-prototype-at-ces-2025/
# 145 - Article already exists in database: https://techcrunch.com/2025/01/07/panasonic-unveils-an-ai-powered-wellness-coach-powered-by-anthropics-claude-at-ces-2025/
# 146 - Article already exists in database: https://techcrunch.com/2025/01/07/hr-software-startup-onpay-was-inspired-by-the-founders-family-payroll-business/
# 147 - Article already exists in database: https://techcrunch.com/2025/01/07/bmws-new-ui-puts-widgets-on-the-windshield-ces-2025/
# 148 - Article already exists in database: https://techcrunch.com/2025/01/07/at-ces-2025-uber-teams-up-with-nvidia-to-scale-autonomous-driving-faster/
# 149 - Article already exists in database: https://techcrunch.com/2025/01/07/what-the-heck-happened-at-fintech-bench/
# 150 - Article already exists in database: https://techcrunch.com/2025/01/07/google-puts-1m-into-3d-design-app-rooms-after-more-than-1-million-rooms-created/
# 151 - Article already exists in database: https://techcrunch.com/2025/01/07/us-government-set-to-launch-its-cyber-trust-mark-cybersecurity-labeling-program-for-internet-connected-devices-in-2025/
# 152 - Article already exists in database: https://techcrunch.com/2025/01/07/radioshack-is-back-kind-of-at-ces-2025/
# 153 - Article already exists in database: https://techcrunch.com/2025/01/07/trump-announces-20b-plan-to-build-new-data-centers-in-the-us/
# 154 - Article already exists in database: https://techcrunch.com/2025/01/07/meticulous-shows-off-its-smart-espresso-machine-at-ces-2025/
# 155 - Article already exists in database: https://techcrunch.com/2025/01/07/employer-com-offers-to-buy-failed-fintech-level-a-week-after-it-makes-offer-for-bench/
# 156 - Article not found or not supported: https://techcrunch.com/video/meet-mirumi-an-adorable-robot-that-sits-on-your-purse-from-ces-2025/
# 157 - Inserted article Peacock is experimenting with mini-games and short videos into database
# 158 - Inserted article Meta to phase back in political content on Facebook, Instagram, and Threads into database
# 159 - Inserted article UK confirms plans to criminalize the creation of sexually explicit deepfake content into database
# 160 - Article not found or not supported: https://techcrunch.com/video/watch-this-robot-vacuum-pick-up-your-dirty-socks-at-ces-2025/
# 161 - Inserted article Ultrahuman stakes a claim to luxury smart rings with trio of 18K gold and pt950 platinum bands into database
# 162 - Inserted article Reddit intros new trends tools for businesses and an AMA ad format into database
# 163 - Inserted article Serve Robotics raises additional $80M as it scales sidewalk delivery robots into database
# 164 - Inserted article Alta Resource breaks down e-waste for rare earth metals that electronics need into database
# 165 - Inserted article Fermata uses computer vision to detect diseases and pests in plants into database
# 166 - Inserted article German Bionic’s new exoskeleton supports 80-pound lifts, revealed at CES 2025 into database
# 167 - Inserted article Razer’s concept gaming chair will heat your butt up before cooling it down into database
# 168 - Article not found or not supported: https://techcrunch.com/video/nvidia-reveals-project-digits-to-power-personal-ai-supercomputers-at-ces-2025/
# 169 - Inserted article Withings launches BPM Vision, a $130 home blood pressure monitor, at CES 2025 into database
# 170 - Inserted article UN aviation agency ‘investigating’ security breach after hacker claims theft of personal data into database
# 171 - Inserted article Getty Images and Shutterstock to merge to form $3.7B stock photo giant into database
# 172 - Inserted article Segway dropped two e-bikes at CES 2025 that are stylish and packed with tech for under $3000 into database
# 173 - Article not found or not supported: https://techcrunch.com/video/watch-jensen-huang-unveil-the-rtx-5090-gpu-at-ces-2025/
# 174 - Inserted article CES 2025: Petcube’s new water fountain aims to protect your cat’s urinary health into database
# 175 - Inserted article Kombu is changing the way we make our ‘booch’ with its modern kombucha brewer at CES 2025 into database
# 176 - Inserted article Acer’s new gaming handheld is ridiculously large into database
# 177 - Inserted article Meta drops fact-checking, loosens its content moderation rules into database
# 178 - Inserted article May Mobility reveals electric autonomous minibus at CES 2025 into database
# 179 - Inserted article NXP to buy automotive safety software firm TTTech Auto for $625M into database
# 180 - Inserted article Just Eat Takeaway completes Grubhub sale to Wonder for a modest $650M into database
# 181 - Inserted article Microsoft plans to invest $3B in AI, cloud in India into database
# 182 - Inserted article Following complaints, Apple to ‘further clarify’ when notification summaries use AI into database
# 183 - Inserted article CES 2025 Press Day: Everything Nvidia, Sony, Toyota, Samsung announced, and more into database
# 184 - Inserted article Nvidia’s Project Digits is a ‘personal AI supercomputer’ into database
# 185 - Inserted article Nvidia is helping humanoid robots learn through Apple Vision Pro instruction into database
# 186 - Inserted article Toyota’s next-generation cars will be built with Nvidia supercomputers and operating system into database
# 187 - Inserted article Nvidia details Mega, a fleet manager for warehouse robots into database
# 188 - Inserted article Nvidia releases its own brand of world models into database
# 189 - Inserted article Nvidia unveils $2,000 RTX 5090 GPU into database
# 190 - Inserted article Anker shows off its solar beach umbrella at CES 2025 into database
# 191 - Inserted article Sony Honda Mobility’s Afeela EV will start at $89,900 into database
# 192 - Inserted article Sony’s CES 2025 press conference: How to watch into database
# 193 - Inserted article Nvidia’s CES 2025 keynote: How to watch into database
# 194 - Inserted article Samsung will unveil the Galaxy S25 on January 22 into database
# 195 - Inserted article Toyota is ‘exploring rockets’ and has made its first investment into Interstellar Technologies into database
# 196 - Inserted article Samsung says its home robot, Ballie, will roll out the first half of 2025 into database
# 197 - Inserted article The US just added Tencent —  which backs US startups — to its list of ‘Chinese military’ companies into database
# 198 - Inserted article Consumer tech spending will break records in 2025 if Trump’s tariffs don’t squash it, CTA predicts into database
# 199 - Inserted article Toyota’s Woven City is open for business and looking for startups into database
# 200 - Inserted article Washington sues T-Mobile over 2021 data breach that spilled 79 million customer records into database
# 201 - Inserted article Meta appoints UFC’s president to its board into database
# 202 - Inserted article Toyota is teaching robot arms to fold t-shirts the Japanese way into database
# 203 - Inserted article Sierra Space CEO Tom Vice steps down, CNBC reports into database
# 204 - Inserted article Goodbye, Dell XPS into database
# 205 - Inserted article Flying Flea electric motorcycles will feature connected services powered by Qualcomm into database
# 206 - Inserted article CISA says ‘no indication’ of wider government hack beyond Treasury into database
# 207 - Inserted article AMD unveils new chips for laptops, desktops, and gaming handhelds at CES 2025 into database
# 208 - Inserted article Bluesky bump from X exodus is slowing down, data shows into database
# 209 - Inserted article Google unveils an AI-powered TV that summarizes the news for you at CES 2025 into database
# 210 - Inserted article Trucks VC launches $70M fund to find the next great batch of transportation startups into database
# 211 - Inserted article Google is forming a new team to build AI that can simulate the physical world into database
# 212 - Inserted article Bosch is making e-bike batteries lockable via an app to deter theft into database
# 213 - Inserted article John Deere’s new robot lawnmower is coming for landscapers’ jobs into database
# 214 - Inserted article Pawport’s upgraded smart pet door debuts at CES into database
# 215 - Inserted article Will.i.am is flogging electronics again into database
# 216 - Inserted article TechCrunch Space: New year, new milestones into database
# 217 - Inserted article Pebble reveals its EV travel trailer designed for digital nomads into database
# 218 - Inserted article Online spending grew 3% to a record $1.2T over holiday period, says Salesforce into database
# 219 - Inserted article Therabody launches Coach, an AI-powered digital recovery platform into database
# 220 - Inserted article RoboForce raises $10 million to create a robot workforce into database
# 221 - Inserted article UK uses AI to tackle ‘bid-rigging’ collusion in public procurement contracts into database
# 222 - Inserted article Qualcomm brings its Snapdragon X chips to mid-range Windows laptops and desktops into database
# 223 - Inserted article How to watch CES 2025’s press conferences into database
# 224 - Inserted article Full Nature Farms launches smart irrigation system at CES 2025 to reduce agricultural water waste into database
# 225 - Inserted article Disney to merge Hulu Live TV with Fubo in groundbreaking deal into database
# 226 - Inserted article Lucid meets production target with 9,029 EV deliveries in 2024 into database
# 227 - Inserted article Bird Buddy expands into insects with Wonder line into database
# 228 - Inserted article Intel shows off its latest chip lineup at CES 2025 into database
# 229 - Inserted article Kidde’s new smoke detectors have Ring technology built in into database
# 230 - Inserted article Soliddd is building smart glasses for people with macular degeneration into database
# 231 - Inserted article Avataar releases new tool to create AI-generated videos for products into database
# 232 - Inserted article Samsung’s CES 2025 press conference: How to watch into database
# 233 - Inserted article Elvie unveils an app-controlled smart bouncer that transforms into a bassinet at CES 2025 into database
# 234 - Inserted article AMD’s CES 2025 press conference: How to watch into database
# 235 - Inserted article OpenAI is losing money on its pricey ChatGPT Pro plan, CEO Sam Altman says into database
# 236 - Inserted article Kirin offers a taste of its electric salt spoon at CES 2025 into database
# 237 - Inserted article Samsung brings live translate to its TVs at CES 2025 into database
# 238 - Inserted article Samsung’s new TVs can find recipes for dishes in shows into database
# 239 - Inserted article Withings’ Omnia is a full-size body-scanning health mirror into database
# 240 - Inserted article OpenAI is turning its attention to ‘superintelligence’ into database
# 241 - Inserted article This fuzzy, purse-mounted robot is designed to ‘delight bystanders’ into database
# 242 - Inserted article Timekettle’s new earbuds offer real-time translation on calls into database
# 243 - Inserted article Circular unveils its next-gen Ring 2 with ECG functionality and AFib detection at CES 2025 into database
# 244 - Inserted article This tiny robot cat will blow on your coffee to cool it off into database
# 245 - Inserted article Birdfy sees your smart bird feeder and raises you a smart birdbath into database
# 246 - Inserted article Accel could raise billions for India, but it’s sticking to $650M into database
# 247 - Inserted article Sam Altman has choice words for the OpenAI board members who fired him into database
# 248 - Inserted article Toyota’s CES 2025 press conference: How to watch into database
# 249 - Inserted article YouTuber LegalEagle sues PayPal over ‘sleeping leech’ Honey extension into database
# 250 - Inserted article Roborock’s Roomba competitor gets a robot arm into database
# 251 - Inserted article Bad news for Adrian Dittmann/Elon Musk truthers into database
# 252 - Inserted article United Airlines accelerates its Starlink rollout, with first commercial flight planned for spring into database
# 253 - Inserted article From forced landings to stuffed animal heads, headhunter Peterson Conway is defense tech’s wildest power broker into database
# 254 - Inserted article Tenable CEO Amit Yoran dies into database
# 255 - Inserted article Lyft will credit NYC riders for congestion fee throughout January into database
# 256 - Inserted article What will this year bring in VC? We asked a few investors into database
# 257 - Inserted article New ship, new year: SpaceX to deploy model Starlink satellites on next Starship launch into database
# 258 - Inserted article Uber CEO Dara Khosrowshahi resigns from self-driving truck startup Aurora’s board into database
# 259 - Inserted article Inside the wild fall and last-minute revival of Bench, the VC-backed accounting startup that imploded over the holidays into database
# 260 - Inserted article These fintech companies are hiring in 2025 after a turbulent year into database
# 261 - Inserted article Scout Motors EVs will have satellite connectivity into database
# 262 - Inserted article ChatGPT: Everything you need to know about the AI-powered chatbot into database
# 263 - Inserted article Generative AI funding reached new heights in 2024 into database
# 264 - Inserted article Microsoft to spend $80 billion in FY’25 on data centers for AI into database
# 265 - Inserted article Turo CEO: Attackers had clean records, so background checks wouldn’t have stopped them into database
# 266 - Inserted article FTC orders AI accessibility startup accessiBe to pay $1M for misleading advertising into database
# 267 - Inserted article Bench saved by the bell, and other last-minute deals that closed 2024 into database
# 268 - Inserted article Hydrogen tax credit rules give startups clarity while boosting nuclear and carbon capture into database
# 269 - Inserted article Venture fund founder sues PayPal, alleging racial discrimination into database
# 270 - Inserted article US sanctions Chinese cyber firm linked to Flax Typhoon hacks into database
# 271 - Inserted article Apple TV+ is free to stream this weekend into database
# 272 - Inserted article These MagSafe earbuds snap on to the back of an iPhone into database
# 273 - Inserted article Electra found a cheap, clean way to purify iron, and it’s raising $257M to make it happen into database
# 274 - Inserted article Online gift card store exposed hundreds of thousands of people’s identity documents into database
# 275 - Inserted article Rivian wraps 2024 with more than 50,000 EVs delivered into database
# 276 - Inserted article Hindustan Unilever in talks to acquire Peak XV-backed Minimalist for up to $350M into database
# 277 - Inserted article Cloudflare’s VPN app among half-dozen pulled from Indian app stores into database
# 278 - Inserted article Peter Thiel-backed venture debt firm Tacora raises $268.7M for new fund into database
# 279 - Inserted article KoBold used AI to find copper — now investors are piling in to the tune of $537M into database
# 280 - Inserted article xAI’s next-gen AI model didn’t arrive on time, adding to a trend into database
# 281 - Inserted article These 55 robotics companies are hiring into database
# 282 - Inserted article Meta policy chief Nick Clegg steps down into database
# 283 - Inserted article New details emerge in Cybertruck explosion outside Trump hotel in Vegas that left 1 dead, 7 injured into database
# 284 - Inserted article CES 2025: What to expect from the year’s first and biggest tech show into database
# 285 - Inserted article Spotify’s partner program for podcast hosts is now available into database
# 286 - Inserted article Thomson Reuters acquires tax automation company SafeSend for $600M into database
# 287 - Inserted article Tesla Cybertruck fails to boost 2024 sales as annual deliveries fall for first time into database
# 288 - Inserted article Apheris rethinks the AI data bottleneck in life science with federated computing into database
# 289 - Inserted article 2025 will be the year climate tech learns to love AI into database
# 290 - Inserted article Telegram rolls out third-party account verification, filters into database
# 291 - Inserted article Chinese government hackers reportedly targeted US Treasury’s sanctions office during December cyberattack into database
# 292 - Inserted article People are playing a new DOOM-themed CAPTCHA into database
# 293 - Inserted article Internal SpaceX documents show the sweet stock deals offered to investors like a16z, Gigafund into database
# 294 - Inserted article Robinhood, already a ‘comeback’ stock, has even more aggressive plans for 2025 into database
# 295 - Inserted article Silicon Valley stifled the AI doom movement in 2024 into database
# 296 - Inserted article OpenAI failed to deliver the opt-out tool it promised by 2025 into database
# 297 - Inserted article Accel closes $650 million for new India fund into database
# All articles inserted into database

# %%
data, text = get_article_content("https://techcrunch.com/2025/01/09/innovaccer-aims-to-become-healthcares-ai-powerhouse-with-275m-series-f/")

# %%
insert_article_to_sql(cursor, data, 'caca', 'maca')

# %%
cursor.execute("rollback")

# %%
data, text = get_article_content('https://techcrunch.com/2025/01/07/feds-investigate-teslas-actual-smart-summon-after-several-crashes/')

# %%
results = summarize_content(text, llm)

# %%
print(results)
# Out:
# ('An investigation has been launched by the National Highway Traffic Safety Administration into 2.56 million Tesla cars following multiple crashes linked to the newly released "Actual Smart Summon" feature. This advanced remote parking capability, which allows vehicles to navigate autonomously to their owners using only cameras, has raised safety concerns after reports of incidents where the cars failed to detect obstacles. Complaints indicate that the system may not provide drivers adequate time to react before a collision occurs, prompting further scrutiny into its reliability. As Tesla continues to innovate in autonomous technology, the implications of this investigation could have significant repercussions for the company and its users.', 'What specific incidents prompted the NHTSA to initiate the investigation into Tesla’s Smart Summon feature?&&&How does the "Actual Smart Summon" differ from the previous version of the Smart Summon feature?&&&What potential consequences could Tesla face from this investigation by the NHTSA?')

# %%
#s-a oprit la al [72]-lea articol inclusiv, reia de la 73; summary-urile deja au fost bagate in db

# %%
print(list(enumerate(total_articles)))
# Out:
# [(0, ('Apple board opposes proposal to abolish DEI programs', 'https://techcrunch.com/2025/01/11/apple-board-opposes-proposal-to-abolish-dei-programs/')), (1, ('Researchers open source Sky-T1, a ‘reasoning’ AI model that can be trained for less than $450', 'https://techcrunch.com/2025/01/11/researchers-open-source-sky-t1-a-reasoning-ai-model-that-can-be-trained-for-less-than-450/')), (2, ('What’s behind ballooning video game budgets?', 'https://techcrunch.com/2025/01/11/whats-behind-ballooning-video-game-budgets/')), (3, ('Everything you missed at CES 2025', 'https://techcrunch.com/2025/01/11/everything-you-missed-at-ces-2025/')), (4, ('I got soaked driving the Arc Sport electric boat', 'https://techcrunch.com/2025/01/11/i-got-soaked-driving-the-arc-sport-electric-boat/')), (5, ('Matt Mullenweg deactivates WordPress contributor accounts over alleged fork plans', 'https://techcrunch.com/2025/01/11/matt-mullenweg-deactivates-wordpress-accounts-of-contributors-planning-a-fork/')), (6, ('Nvidia’s AI empire: A look at its top startup investments', 'https://techcrunch.com/2025/01/11/nvidias-ai-empire-a-look-at-its-top-startup-investments/')), (7, ('Snappy acquires swag-gifting startup Covver as it seeks to roll-up players', 'https://techcrunch.com/2025/01/10/snappy-aquires-swag-gifting-startup-covver-as-it-seks-to-roll-up-players/')), (8, ('Microsoft accuses group of developing tool to abuse its AI service in new lawsuit', 'https://techcrunch.com/2025/01/10/microsoft-accuses-group-of-developing-tool-to-abuse-its-ai-service-in-new-lawsuit/')), (9, ('Mark Zuckerberg defends Meta’s latest pivot in three-hour Joe Rogan interview', 'https://techcrunch.com/2025/01/10/mark-zuckerberg-defends-metas-latest-pivot-in-three-hour-joe-rogan-interview/')), (10, ('These startups are making smarter canes for people with visual impairments', 'https://techcrunch.com/2025/01/10/these-startups-are-making-smarter-canes-for-people-with-visual-impairments/')), (11, ('A drone punched a hole into an LA firefighting plane', 'https://techcrunch.com/2025/01/10/a-drone-punched-a-hole-into-an-la-firefighting-plane/')), (12, ('Bench customers are now being forced to hand over their data or risk losing it, they say', 'https://techcrunch.com/2025/01/10/bench-customers-are-now-being-forced-to-hand-over-their-data-or-risk-losing-it-they-say/')), (13, ('Amazon curbs some DEI programs', 'https://techcrunch.com/2025/01/10/amazon-curbs-some-dei-programs/')), (14, ('TikTok ban: How both sides made their case to the Supreme Court and what the justices asked', 'https://techcrunch.com/2025/01/10/tiktok-ban-how-both-sides-made-their-case-to-the-supreme-court-and-what-the-justices-asked/')), (15, ('New OpenAI job listings reveal the company’s robotics plans', 'https://techcrunch.com/2025/01/10/new-openai-job-listings-reveal-its-robotics-plans/')), (16, ('How OpenAI’s bot crushed this seven-person company’s website ‘like a DDoS attack’', 'https://techcrunch.com/2025/01/10/how-openais-bot-crushed-this-seven-person-companys-web-site-like-a-ddos-attack/')), (17, ('VCs say AI companies need proprietary data to stand out from the pack', 'https://techcrunch.com/2025/01/10/vcs-say-ai-companies-need-proprietary-data-to-stand-out-from-the-pack/')), (18, ('Lenovo’s latest form factors prove PCs can still be fun', 'https://techcrunch.com/2025/01/10/lenovos-latest-form-factors-prove-pcs-can-still-be-fun/')), (19, ('How to delete Facebook, Instagram, and Threads', 'https://techcrunch.com/2025/01/10/how-to-delete-facebook-instagram-and-threads/')), (20, ('Riding in a Zoox robotaxi at CES 2025: Everything that went right and wrong', 'https://techcrunch.com/2025/01/10/riding-in-a-zoox-robotaxi-at-ces-2025-everything-that-went-right-and-wrong/')), (21, ('Hugging Face settles suit with AI startup FriendliAI, which had accused it of patent infringement', 'https://techcrunch.com/2025/01/10/hugging-face-settles-suit-with-ai-startup-friendliai-which-had-accused-it-of-patent-infringement/')), (22, ('M ...

# %%
def get_author(url):
    page = requests.get(url)
    soup = BeautifulSoup(page.content, "html.parser")

    check404 = soup.find("body", class_="error404")
    isLive = soup.find("span", class_="wp-block-techcrunch-storyline-hero__live")
    year = url.split("/")[3]

    if check404 or isLive or year != "2025":
        return None


    
    try:                 
        author = soup.find("a", class_="wp-block-tc23-author-card-name__link")
        if author is None:
            author = soup.find("a", class_="post-authors-list__author")
            if author is None:
                author = "anonymous"
            else: 
                author = author.text.strip()
        else:
            author = author.text.strip()
        
        author = author.replace("'", "’")
    

    except:
        raise Exception("Error parsing article content for url", url)
        
    return author

# %%
def populate_author_column():
    print("started")
    cursor.execute("select link from article")
    print("executed")
    links = cursor.fetchall()
    print("fetched")
    for idx, link in enumerate(links):
        print(f"{idx} - Updating author for article {link}")
        author = get_author(link[0])
        cursor.execute(f"""update article set author = '{author}' where link = '{link[0]}'""")
        cursor.execute("commit")

# %%
populate_author_column()
# Out:
# started
# executed
# fetched
# 0 - Updating author for article ('https://techcrunch.com/2025/01/09/watch-duty-surpasses-chatgpt-as-top-free-app-on-app-store-as-california-fires-spread/',)
# 1 - Updating author for article ('https://techcrunch.com/2025/01/09/googles-daily-listen-ai-feature-generates-a-podcast-based-on-your-discover-feed/',)
# 2 - Updating author for article ('https://techcrunch.com/2025/01/09/doublepoint-launches-free-apple-watch-app-to-control-devices-with-hand-gestures/',)
# 3 - Updating author for article ('https://techcrunch.com/2025/01/09/google-searches-for-deleting-facebook-instagram-explode-after-meta-ends-fact-checking/',)
# 4 - Updating author for article ('https://techcrunch.com/2025/01/09/innovaccer-aims-to-become-healthcares-ai-powerhouse-with-275m-series-f/',)
# 5 - Updating author for article ('https://techcrunch.com/2025/01/09/tesla-directors-to-pay-up-to-919-million-to-settle-claims-they-overpaid-themselves/',)
# 6 - Updating author for article ('https://techcrunch.com/2025/01/09/rounded-is-an-ai-orchestration-platform-that-lets-anyone-build-an-ai-voice-agent/',)
# 7 - Updating author for article ('https://techcrunch.com/2025/01/09/biosphere-zaps-germs-with-uv-light-to-make-biomanufacturing-cheaper/',)
# 8 - Updating author for article ('https://techcrunch.com/2025/01/09/prettydamnquick-snaps-up-25m-to-speed-up-online-checkout/',)
# 9 - Updating author for article ('https://techcrunch.com/2025/01/09/grand-games-the-turkish-gaming-startup-behind-pouring-game-magic-sort-drinks-up-30m/',)
# 10 - Updating author for article ('https://techcrunch.com/2025/01/09/defiant-is-a-new-european-vc-firm-that-uses-data-and-products-to-make-better-investments/',)
# 11 - Updating author for article ('https://techcrunch.com/2025/01/09/xocean-raises-119m-to-capture-ocean-data-with-uncrewed-surface-vessels/',)
# 12 - Updating author for article ('https://techcrunch.com/2025/01/09/vlc-tops-6-billion-downloads-previews-ai-generated-subtitles/',)
# 13 - Updating author for article ('https://techcrunch.com/2025/01/08/elon-musk-agrees-that-weve-exhausted-ai-training-data/',)
# 14 - Updating author for article ('https://techcrunch.com/2025/01/08/we-talked-to-the-guy-who-was-stuck-in-a-waymo-robotaxi-on-an-dizzying-loop/',)
# 15 - Updating author for article ('https://techcrunch.com/2025/01/08/the-u-s-has-a-new-cybersecurity-safety-label-for-smart-devices/',)
# 16 - Updating author for article ('https://techcrunch.com/2025/01/08/the-liberlive-c1-stringless-instrument-isnt-a-guitar-and-thats-fine/',)
# 17 - Updating author for article ('https://techcrunch.com/2025/01/08/flipkart-taps-dunzo-founder-to-lead-quick-commerce-push/',)
# 18 - Updating author for article ('https://techcrunch.com/2025/01/08/hallidays-489-smart-glasses-beam-a-tiny-screen-to-your-eye/',)
# 19 - Updating author for article ('https://techcrunch.com/2025/01/08/this-1500-ipad-bundle-will-rickroll-your-family-after-you-die/',)
# 20 - Updating author for article ('https://techcrunch.com/2025/01/08/pickpad-addresses-the-chaos-of-restaurant-takeout/',)
# 21 - Updating author for article ('https://techcrunch.com/2025/01/08/mastodon-ceo-calls-metas-moderation-changes-deeply-troubling-warns-users-cross-posting-from-threads/',)
# 22 - Updating author for article ('https://techcrunch.com/2025/01/08/gamers-cant-fathom-how-6x-ceo-elon-musk-found-time-to-best-diablo-iv/',)
# 23 - Updating author for article ('https://techcrunch.com/2025/01/08/this-basketball-robot-uses-ai-to-rebound-the-ball-after-you-shoot/',)
# 24 - Updating author for article ('https://techcrunch.com/2025/01/08/gridwares-boxes-literally-listen-to-power-lines-to-find-outages/',)
# 25 - Updating author for article ('https://techcrunch.com/2025/01/08/ai-researcher-francois-chollet-is-co-founding-a-nonprofit-to-build-benchmarks-for-agi/',)
# 26 - Updating author for article ('https://techcrunch.com/2025/01/08/this-week-in-ai-more-capable-ai-is-coming-but-will-its-benefits-be-evenly-distributed/',)
# 27 - Updating author for article ('https://techcrunch.com/2025/01/08/triller-launches-a-tool-to-back-up-users-tiktoks-ahead-of-the-u-s-ban-deadline/',)
# 28 - Updating author for article ('https://techcrunch.com/2025/01/08/tonals-new-strength-training-system-arrives-with-refreshed-hardware-and-new-workouts/',)
# 29 - Updating author for article ('https://techcrunch.com/2025/01/08/boston-dynamics-settles-patent-suit-with-military-robotics-firm-ghost/',)
# 30 - Updating author for article ('https://techcrunch.com/2025/01/08/ukrainian-hackers-take-credit-for-hacking-russian-isp-that-wiped-out-servers-and-caused-internet-outages/',)
# 31 - Updating author for article ('https://techcrunch.com/2025/01/08/omi-a-competitor-to-friend-wants-to-boost-your-productivity-using-ai-and-a-brain-interface/',)
# 32 - Updating author for article ('https://techcrunch.com/2025/01/08/grove-cuts-clinical-trial-enrollment-time-with-ai/',)
# 33 - Updating author for article ('https://techcrunch.com/2025/01/08/microsoft-rolls-back-its-bing-image-creator-model-after-users-complain-of-degraded-quality/',)
# 34 - Updating author for article ('https://techcrunch.com/2025/01/08/former-ceo-of-moviepass-parent-company-pleads-guilty-to-fraud-over-unlimited-plan/',)
# 35 - Updating author for article ('https://techcrunch.com/2025/01/08/japan-says-chinese-hackers-targeted-its-government-and-tech-companies-for-years/',)
# 36 - Updating author for article ('https://techcrunch.com/2025/01/08/edtech-giant-powerschool-says-hackers-accessed-personal-data-of-students-and-teachers/',)
# 37 - Updating author for article ('https://techcrunch.com/2025/01/08/vay-expands-driverless-car-sharing-fleet-in-las-vegas/',)
# 38 - Updating author for article ('https://techcrunch.com/2025/01/08/eu-court-fines-european-commission-for-breaching-its-own-data-privacy-laws/',)
# 39 - Updating author for article ('https://techcrunch.com/2025/01/08/livestream-shopping-app-whatnot-raises-265m-pinning-valuation-at-nearly-5b/',)
# 40 - Updating author for article ('https://techcrunch.com/2025/01/08/healthcare-analytics-platform-h1-has-acquired-ribbon-backed-by-a16z-and-general-catalyst/',)
# 41 - Updating author for article ('https://techcrunch.com/2025/01/08/un-aviation-agency-confirms-hacker-breached-recruitment-database-to-access-thousands-of-records/',)
# 42 - Updating author for article ('https://techcrunch.com/2025/01/08/microsoft-backs-its-3b-ai-push-in-india-with-public-and-private-sector-deals/',)
# 43 - Updating author for article ('https://techcrunch.com/2025/01/08/casio-says-hackers-stole-personal-data-of-8500-people-during-october-ransomware-attack/',)
# 44 - Updating author for article ('https://techcrunch.com/2025/01/08/sirens-smart-sock-for-diabetics-secures-strategic-funding-round/',)
# 45 - Updating author for article ('https://techcrunch.com/2025/01/07/delta-skymiles-members-can-now-earn-miles-riding-with-uber-ending-its-deal-with-lyft/',)
# 46 - Updating author for article ('https://techcrunch.com/2025/01/07/sam-altmans-family-responds-to-lawsuit-alleging-he-sexually-assaulted-his-sister/',)
# 47 - Updating author for article ('https://techcrunch.com/2025/01/07/delta-air-lines-announces-an-ai-powered-assistant-in-its-mobile-app-and-free-onboard-youtube-premium-and-music-at-ces-2025/',)
# 48 - Updating author for article ('https://techcrunch.com/2025/01/07/zeekr-rt-the-robotaxi-built-for-waymo-has-the-tiniest-wipers/',)
# 49 - Updating author for article ('https://techcrunch.com/2025/01/07/indian-government-websites-are-still-redirecting-users-to-scam-sites/',)
# 50 - Updating author for article ('https://techcrunch.com/2025/01/07/silicon-valley-is-so-dominant-again-its-startups-devoured-over-half-of-all-global-vc-funding-in-2024/',)
# 51 - Updating author for article ('https://techcrunch.com/2025/01/07/this-baseball-radar-gun-plugs-into-an-iphone/',)
# 52 - Updating author for article ('https://techcrunch.com/2025/01/07/ces-2025-day-1-honda-bmw-xs-victory-lap-and-the-first-show-floor-gadget-reveals/',)
# 53 - Updating author for article ('https://techcrunch.com/2025/01/11/i-got-soaked-driving-the-arc-sport-electric-boat/',)
# 54 - Updating author for article ('https://techcrunch.com/2025/01/11/matt-mullenweg-deactivates-wordpress-accounts-of-contributors-planning-a-fork/',)
# 55 - Updating author for article ('https://techcrunch.com/2025/01/11/researchers-open-source-sky-t1-a-reasoning-ai-model-that-can-be-trained-for-less-than-450/',)
# 56 - Updating author for article ('https://techcrunch.com/2025/01/11/whats-behind-ballooning-video-game-budgets/',)
# 57 - Updating author for article ('https://techcrunch.com/2025/01/11/everything-you-missed-at-ces-2025/',)
# 58 - Updating author for article ('https://techcrunch.com/2025/01/11/nvidias-ai-empire-a-look-at-its-top-startup-investments/',)
# 59 - Updating author for article ('https://techcrunch.com/2025/01/10/snappy-aquires-swag-gifting-startup-covver-as-it-seks-to-roll-up-players/',)
# 60 - Updating author for article ('https://techcrunch.com/2025/01/10/microsoft-accuses-group-of-developing-tool-to-abuse-its-ai-service-in-new-lawsuit/',)
# 61 - Updating author for article ('https://techcrunch.com/2025/01/10/mark-zuckerberg-defends-metas-latest-pivot-in-three-hour-joe-rogan-interview/',)
# 62 - Updating author for article ('https://techcrunch.com/2025/01/10/these-startups-are-making-smarter-canes-for-people-with-visual-impairments/',)
# 63 - Updating author for article ('https://techcrunch.com/2025/01/10/a-drone-punched-a-hole-into-an-la-firefighting-plane/',)
# 64 - Updating author for article ('https://techcrunch.com/2025/01/10/bench-customers-are-now-being-forced-to-hand-over-their-data-or-risk-losing-it-they-say/',)
# 65 - Updating author for article ('https://techcrunch.com/2025/01/10/amazon-curbs-some-dei-programs/',)
# 66 - Updating author for article ('https://techcrunch.com/2025/01/10/tiktok-ban-how-both-sides-made-their-case-to-the-supreme-court-and-what-the-justices-asked/',)
# 67 - Updating author for article ('https://techcrunch.com/2025/01/10/new-openai-job-listings-reveal-its-robotics-plans/',)
# 68 - Updating author for article ('https://techcrunch.com/2025/01/10/how-openais-bot-crushed-this-seven-person-companys-web-site-like-a-ddos-attack/',)
# 69 - Updating author for article ('https://techcrunch.com/2025/01/10/vcs-say-ai-companies-need-proprietary-data-to-stand-out-from-the-pack/',)
# 70 - Updating author for article ('https://techcrunch.com/2025/01/10/lenovos-latest-form-factors-prove-pcs-can-still-be-fun/',)
# 71 - Updating author for article ('https://techcrunch.com/2025/01/10/how-to-delete-facebook-instagram-and-threads/',)
# 72 - Updating author for article ('https://techcrunch.com/2025/01/10/riding-in-a-zoox-robotaxi-at-ces-2025-everything-that-went-right-and-wrong/',)
# 73 - Updating author for article ('https://techcrunch.com/2025/01/10/hugging-face-settles-suit-with-ai-startup-friendliai-which-had-accused-it-of-patent-infringement/',)
# 74 - Updating author for article ('https://techcrunch.com/2025/01/10/meet-the-chinese-typhoon-hackers-preparing-for-war/',)
# 75 - Updating author for article ('https://techcrunch.com/2025/01/10/shein-is-still-looking-to-ipo/',)
# 76 - Updating author for article ('https://techcrunch.com/2025/01/10/meta-eliminates-dei-programs/',)
# 77 - Updating author for article ('https://techcrunch.com/2025/01/10/january-almost-had-its-first-pentacorn-and-other-startup-news/',)
# 78 - Updating author for article ('https://techcrunch.com/2025/01/10/eu-approves-35b-synopsys-and-ansys-merger-subject-to-divestment-conditions/',)
# 79 - Updating author for article ('https://techcrunch.com/2025/01/10/overhaul-keeps-tabs-on-cargo-for-customers-like-microsoft-and-dyson/',)
# 80 - Updating author for article ('https://techcrunch.com/2025/01/10/the-new-atari-handheld-knows-its-market/',)
# 81 - Updating author for article ('https://techcrunch.com/2025/01/10/tiktok-pleads-its-case-against-sell-or-ban-law-before-supreme-court/',)
# 82 - Updating author for article ('https://techcrunch.com/2025/01/10/us-government-charges-operators-of-crypto-mixing-service-used-by-north-korea-and-ransomware-gangs/',)
# 83 - Updating author for article ('https://techcrunch.com/2025/01/10/china-hacked-us-treasurys-cfius-which-reviews-foreign-investments-for-national-security-risks/',)
# 84 - Updating author for article ('https://techcrunch.com/2025/01/10/cannabis-company-stiiizy-says-hackers-accessed-customers-id-documents/',)
# 85 - Updating author for article ('https://techcrunch.com/2025/01/10/gumloop-founded-in-a-bedroom-in-vancouver-lets-users-automate-tasks-with-drag-and-drop-modules/',)
# 86 - Updating author for article ('https://techcrunch.com/2025/01/10/automattic-says-it-will-reduce-its-contribution-to-wordpress-core-project-to-match-wp-engine/',)
# 87 - Updating author for article ('https://techcrunch.com/2025/01/09/beams-secures-9m-series-a-to-digitize-uk-home-renovation-market/',)
# 88 - Updating author for article ('https://techcrunch.com/2025/01/09/india-rupay-upi-payment-push-is-cutting-out-visa-and-mastercard/',)
# 89 - Updating author for article ('https://techcrunch.com/2025/01/09/x-says-it-is-rolling-out-labels-for-parody-accounts/',)
# 90 - Updating author for article ('https://techcrunch.com/2025/01/09/every-smartphone-in-la-accidentally-received-a-wildfire-evacuation-alert/',)
# 91 - Updating author for article ('https://techcrunch.com/2025/01/09/this-security-system-shoots-paintballs-at-intruders/',)
# 92 - Updating author for article ('https://techcrunch.com/2025/01/09/tesla-launches-new-look-model-y-in-china/',)
# 93 - Updating author for article ('https://techcrunch.com/2025/01/09/hippocratic-ai-raises-141m-for-creating-patient-facing-ai-agents/',)
# 94 - Updating author for article ('https://techcrunch.com/2025/01/09/nvidias-ai-avatar-sat-on-my-computer-screen-and-weirded-me-out/',)
# 95 - Updating author for article ('https://techcrunch.com/2025/01/09/icon-a-builder-of-3d-printed-homes-last-valued-around-2-billion-cuts-about-25-of-staff/',)
# 96 - Updating author for article ('https://techcrunch.com/2025/01/09/defense-startup-epirus-in-talks-to-raise-over-150m-potentially-cutting-valuation/',)
# 97 - Updating author for article ('https://techcrunch.com/2025/01/09/apptroniks-apollo-humanoid-robot-gets-to-work-at-ces-2025/',)
# 98 - Updating author for article ('https://techcrunch.com/2025/01/09/tiktok-tells-la-staff-impacted-by-wildfires-to-use-personal-sick-hours-if-they-cant-work-from-home/',)
# 99 - Updating author for article ('https://techcrunch.com/2025/01/09/chatgpts-newest-feature-lets-user-assign-it-traits-like-chatty-and-gen-z/',)
# 100 - Updating author for article ('https://techcrunch.com/2025/01/09/autonomous-vehicles-are-having-a-moment-and-other-vibes-from-ces-2025/',)
# 101 - Updating author for article ('https://techcrunch.com/2025/01/09/ces-2025-where-have-all-the-us-automakers-gone/',)
# 102 - Updating author for article ('https://techcrunch.com/2025/01/09/google-folds-more-ai-teams-into-deepmind-to-accelerate-the-research-to-developer-pipeline/',)
# 103 - Updating author for article ('https://techcrunch.com/2025/01/09/scale-ai-hit-by-its-second-employee-wage-lawsuit-in-less-than-a-month/',)
# 104 - Updating author for article ('https://techcrunch.com/2025/01/09/y-combinator-scored-a-surprise-win-when-larry-page-came-to-speak/',)
# 105 - Updating author for article ('https://techcrunch.com/2025/01/09/these-are-ces-2025s-least-repairable-and-sustainable-gadgets-according-to-ifixit/',)
# 106 - Updating author for article ('https://techcrunch.com/2025/01/09/doorbox-debuts-its-new-and-improved-smart-delivery-box-at-ces-2025/',)
# 107 - Updating author for article ('https://techcrunch.com/2025/01/09/mark-zuckerberg-gave-metas-llama-team-the-ok-to-train-on-copyrighted-works-filing-claims/',)
# 108 - Updating author for article ('https://techcrunch.com/2025/01/09/facebook-awards-researcher-100000-for-finding-bug-that-granted-internal-access/',)
# 109 - Updating author for article ('https://techcrunch.com/2025/01/09/scout-motors-ceo-scott-keogh-interview-ces-2025/',)
# 110 - Updating author for article ('https://techcrunch.com/2025/01/09/ces-2025-the-weirdest-tech-products-and-claims-from-this-years-event/',)
# 111 - Updating author for article ('https://techcrunch.com/2025/01/07/feds-investigate-teslas-actual-smart-summon-after-several-crashes/',)
# 112 - Updating author for article ('https://techcrunch.com/2025/01/07/aws-says-itll-invest-at-least-11b-to-expand-data-center-infrastructure-in-georgia/',)
# 113 - Updating author for article ('https://techcrunch.com/2025/01/07/ftc-accuses-gig-work-app-handy-of-misleading-ads-and-opaque-fees-for-workers/',)
# 114 - Updating author for article ('https://techcrunch.com/2025/01/07/you-can-plug-a-second-mic-into-shures-new-mv7i/',)
# 115 - Updating author for article ('https://techcrunch.com/2025/01/07/nuclear-startup-deep-fission-plans-to-bury-micro-reactors-to-power-data-centers/',)
# 116 - Updating author for article ('https://techcrunch.com/2025/01/07/chinese-vcs-are-hounding-failed-founders-to-claw-back-their-investments/',)
# 117 - Updating author for article ('https://techcrunch.com/2025/01/07/threads-prototypes-custom-display-names-and-cover-images-for-profiles/',)
# 118 - Updating author for article ('https://techcrunch.com/2025/01/07/anthropic-reportedly-in-talks-to-raise-2b-at-60b-valuation-led-by-lightspeed/',)
# 119 - Updating author for article ('https://techcrunch.com/2025/01/07/xpeng-aero-ht-unveils-flying-car-thats-part-van-part-evtol-at-ces-2025/',)
# 120 - Updating author for article ('https://techcrunch.com/2025/01/07/south-park-commons-is-raising-40m-for-an-india-specific-fund/',)
# 121 - Updating author for article ('https://techcrunch.com/2025/01/07/telegram-reports-spike-in-sharing-user-data-with-law-enforcement/',)
# 122 - Updating author for article ('https://techcrunch.com/2025/01/07/honda-reveals-its-futuristic-0-suv-prototype-at-ces-2025/',)
# 123 - Updating author for article ('https://techcrunch.com/2025/01/07/panasonic-unveils-an-ai-powered-wellness-coach-powered-by-anthropics-claude-at-ces-2025/',)
# 124 - Updating author for article ('https://techcrunch.com/2025/01/07/hr-software-startup-onpay-was-inspired-by-the-founders-family-payroll-business/',)
# 125 - Updating author for article ('https://techcrunch.com/2025/01/07/bmws-new-ui-puts-widgets-on-the-windshield-ces-2025/',)
# 126 - Updating author for article ('https://techcrunch.com/2025/01/07/at-ces-2025-uber-teams-up-with-nvidia-to-scale-autonomous-driving-faster/',)
# 127 - Updating author for article ('https://techcrunch.com/2025/01/07/what-the-heck-happened-at-fintech-bench/',)
# 128 - Updating author for article ('https://techcrunch.com/2025/01/07/google-puts-1m-into-3d-design-app-rooms-after-more-than-1-million-rooms-created/',)
# 129 - Updating author for article ('https://techcrunch.com/2025/01/07/us-government-set-to-launch-its-cyber-trust-mark-cybersecurity-labeling-program-for-internet-connected-devices-in-2025/',)
# 130 - Updating author for article ('https://techcrunch.com/2025/01/07/radioshack-is-back-kind-of-at-ces-2025/',)
# 131 - Updating author for article ('https://techcrunch.com/2025/01/07/trump-announces-20b-plan-to-build-new-data-centers-in-the-us/',)
# 132 - Updating author for article ('https://techcrunch.com/2025/01/07/meticulous-shows-off-its-smart-espresso-machine-at-ces-2025/',)
# 133 - Updating author for article ('https://techcrunch.com/2025/01/07/employer-com-offers-to-buy-failed-fintech-level-a-week-after-it-makes-offer-for-bench/',)
# 134 - Updating author for article ('https://techcrunch.com/2025/01/07/peacock-is-experimenting-with-mini-games-and-short-videos/',)
# 135 - Updating author for article ('https://techcrunch.com/2025/01/07/meta-to-phase-back-in-political-content-on-facebook-instagram-and-threads/',)
# 136 - Updating author for article ('https://techcrunch.com/2025/01/07/uk-confirms-plans-to-criminalize-the-creation-of-sexually-explicit-deepfake-content/',)
# 137 - Updating author for article ('https://techcrunch.com/2025/01/07/ultrahuman-stakes-a-claim-to-luxury-smart-rings-with-trio-of-18k-gold-and-pt950-platinum-bands/',)
# 138 - Updating author for article ('https://techcrunch.com/2025/01/07/reddit-intros-new-trends-tools-for-businesses-and-an-ama-ad-format/',)
# 139 - Updating author for article ('https://techcrunch.com/2025/01/07/serve-robotics-raises-additional-80m-as-it-scales-sidewalk-delivery-robots/',)
# 140 - Updating author for article ('https://techcrunch.com/2025/01/07/alta-resource-breaks-down-e-waste-for-rare-earth-metals-that-electronics-need/',)
# 141 - Updating author for article ('https://techcrunch.com/2025/01/07/fermata-uses-computer-vision-to-detect-diseases-and-pests-in-plants/',)
# 142 - Updating author for article ('https://techcrunch.com/2025/01/07/german-bionics-new-exoskeleton-supports-80-pound-lifts-revealed-at-ces-2025/',)
# 143 - Updating author for article ('https://techcrunch.com/2025/01/07/razers-concept-gaming-chair-will-heat-your-butt-up-cool-it-down/',)
# 144 - Updating author for article ('https://techcrunch.com/2025/01/07/withings-launches-bpm-vision-a-130-home-blood-pressure-monitor-at-ces-2025/',)
# 145 - Updating author for article ('https://techcrunch.com/2025/01/07/un-aviation-agency-investigating-security-breach-after-hacker-claims-theft-of-personal-data/',)
# 146 - Updating author for article ('https://techcrunch.com/2025/01/07/getty-images-and-shutterstock-will-merge-to-form-37-billion-stock-photo-giant/',)
# 147 - Updating author for article ('https://techcrunch.com/2025/01/07/segway-dropped-two-e-bikes-at-ces-2025-that-are-stylish-and-packed-with-tech-for-under-3000/',)
# 148 - Updating author for article ('https://techcrunch.com/2025/01/07/ces-2025-petcubes-new-water-fountain-aims-to-protect-your-cats-urinary-health/',)
# 149 - Updating author for article ('https://techcrunch.com/2025/01/07/kombu-is-changing-the-way-we-make-our-booch-with-its-modern-kombucha-brewer-at-ces-2025/',)
# 150 - Updating author for article ('https://techcrunch.com/2025/01/07/acers-new-gaming-handheld-is-ridiculously-large/',)
# 151 - Updating author for article ('https://techcrunch.com/2025/01/07/meta-drops-fact-checking-and-loosens-its-content-moderation-rules/',)
# 152 - Updating author for article ('https://techcrunch.com/2025/01/07/may-mobility-reveals-electric-autonomous-minibus-at-ces-2025/',)
# 153 - Updating author for article ('https://techcrunch.com/2025/01/07/nxp-to-buy-automotive-safety-software-firm-tttech-auto-for-625m/',)
# 154 - Updating author for article ('https://techcrunch.com/2025/01/07/just-eat-takeaway-completes-grubhub-sale-to-wonder-for-a-modest-650m/',)
# 155 - Updating author for article ('https://techcrunch.com/2025/01/07/microsoft-to-pump-3-billion-into-cloud-and-ai-push-in-india/',)
# 156 - Updating author for article ('https://techcrunch.com/2025/01/06/following-complaints-apple-to-further-clarify-when-notification-summaries-use-ai/',)
# 157 - Updating author for article ('https://techcrunch.com/2025/01/06/ces-2025-press-day-everything-nvidia-sony-toyota-samsung-announced-and-more/',)
# 158 - Updating author for article ('https://techcrunch.com/2025/01/06/nvidias-project-digits-is-a-personal-ai-computer/',)
# 159 - Updating author for article ('https://techcrunch.com/2025/01/06/nvidia-is-helping-humanoid-robots-learn-through-apple-vision-pro-instruction/',)
# 160 - Updating author for article ('https://techcrunch.com/2025/01/06/toyotas-next-generation-cars-will-be-built-with-nvidia-supercomputers-and-operating-system/',)
# 161 - Updating author for article ('https://techcrunch.com/2025/01/06/nvidia-details-mega-warehouse-robot-fleet-management-simulator/',)
# 162 - Updating author for article ('https://techcrunch.com/2025/01/06/nvidia-releases-its-own-brand-of-world-models/',)
# 163 - Updating author for article ('https://techcrunch.com/2025/01/06/nvidia-unveils-rtx-5090-gpu/',)
# 164 - Updating author for article ('https://techcrunch.com/2025/01/06/anker-shows-off-its-solar-beach-umbrella-at-ces-2025/',)
# 165 - Updating author for article ('https://techcrunch.com/2025/01/06/sony-honda-mobilitys-afeela-ev-will-start-at-89900/',)
# 166 - Updating author for article ('https://techcrunch.com/2025/01/06/sonys-ces-2025-press-conference-how-to-watch/',)
# 167 - Updating author for article ('https://techcrunch.com/2025/01/06/nvidias-ces-2025-keynote-how-to-watch/',)
# 168 - Updating author for article ('https://techcrunch.com/2025/01/06/samsung-will-unveil-the-galaxy-s25-on-january-22/',)
# 169 - Updating author for article ('https://techcrunch.com/2025/01/06/toyota-is-exploring-rockets-made-first-investment-interstellar-technologies/',)
# 170 - Updating author for article ('https://techcrunch.com/2025/01/06/samsung-says-its-home-robot-ballie-will-roll-out-this-year/',)
# 171 - Updating author for article ('https://techcrunch.com/2025/01/06/the-us-just-added-tencent-to-its-list-of-chinese-military-companies/',)
# 172 - Updating author for article ('https://techcrunch.com/2025/01/06/consumer-tech-spending-will-break-records-in-2025-if-trumps-tariffs-dont-squash-it-cta-predicts/',)
# 173 - Updating author for article ('https://techcrunch.com/2025/01/06/toyotas-woven-city-is-open-for-business-and-looking-for-startups/',)
# 174 - Updating author for article ('https://techcrunch.com/2025/01/06/washington-sues-t-mobile-over-2021-data-breach-that-spilled-79-million-customer-records/',)
# 175 - Updating author for article ('https://techcrunch.com/2025/01/06/meta-appoints-ufcs-president-to-its-board/',)
# 176 - Updating author for article ('https://techcrunch.com/2025/01/06/toyota-is-teaching-robot-arms-to-fold-t-shirts-the-japanese-way/',)
# 177 - Updating author for article ('https://techcrunch.com/2025/01/06/sierra-space-ceo-tom-vice-steps-down-cnbc-reports/',)
# 178 - Updating author for article ('https://techcrunch.com/2025/01/06/goodbye-dell-xps/',)
# 179 - Updating author for article ('https://techcrunch.com/2025/01/06/flying-flea-electric-motorcycles-will-feature-connected-services-powered-by-qualcomm/',)
# 180 - Updating author for article ('https://techcrunch.com/2025/01/06/cisa-says-no-indication-of-wider-government-hack-beyond-treasury/',)
# 181 - Updating author for article ('https://techcrunch.com/2025/01/06/amd-unveils-new-chips-for-laptops-desktops-and-gaming-handhelds/',)
# 182 - Updating author for article ('https://techcrunch.com/2025/01/06/bluesky-bump-from-x-exodus-is-slowing-down-data-shows/',)
# 183 - Updating author for article ('https://techcrunch.com/2025/01/06/google-unveils-an-ai-powered-tv-that-summarizes-the-news-for-you-at-ces-2025/',)
# 184 - Updating author for article ('https://techcrunch.com/2025/01/06/trucks-vc-launches-70m-fund-to-find-the-next-great-batch-of-transportation-startups/',)
# 185 - Updating author for article ('https://techcrunch.com/2025/01/06/google-is-forming-a-new-team-to-build-ai-that-can-simulate-the-physical-world/',)
# 186 - Updating author for article ('https://techcrunch.com/2025/01/06/bosch-is-making-e-bike-batteries-lockable-via-an-app-to-deter-theft/',)
# 187 - Updating author for article ('https://techcrunch.com/2025/01/06/john-deeres-new-robot-lawnmower-is-coming-for-landscapers-jobs/',)
# 188 - Updating author for article ('https://techcrunch.com/2025/01/06/pawports-upgraded-smart-pet-door-debuts-at-ces/',)
# 189 - Updating author for article ('https://techcrunch.com/2025/01/06/will-i-am-is-flogging-electronics-again/',)
# 190 - Updating author for article ('https://techcrunch.com/2025/01/06/techcrunch-space-new-year-new-milestones/',)
# 191 - Updating author for article ('https://techcrunch.com/2025/01/06/pebble-reveals-its-ev-travel-trailer-designed-for-digital-nomads/',)
# 192 - Updating author for article ('https://techcrunch.com/2025/01/06/online-spending-grew-3-to-a-record-1-2t-over-holiday-period-says-salesforce/',)
# 193 - Updating author for article ('https://techcrunch.com/2025/01/06/therabody-launches-coach-an-ai-powered-digital-recovery-app/',)
# 194 - Updating author for article ('https://techcrunch.com/2025/01/06/roboforce-raises-10-millions-to-create-a-robot-workforce/',)
# 195 - Updating author for article ('https://techcrunch.com/2025/01/06/uk-uses-ai-to-tackle-bid-rigging-collusion-in-public-procurement-contracts/',)
# 196 - Updating author for article ('https://techcrunch.com/2025/01/06/qualcomm-brings-its-snapdragon-x-chips-to-more-affordable-windows-laptops-and-desktops/',)
# 197 - Updating author for article ('https://techcrunch.com/2025/01/06/how-to-watch-ces-2025s-press-conferences/',)
# 198 - Updating author for article ('https://techcrunch.com/2025/01/06/full-nature-farms-launches-smart-irrigation-system-at-ces-2025-to-reduce-agricultural-water-waste/',)
# 199 - Updating author for article ('https://techcrunch.com/2025/01/06/disney-to-merge-hulu-live-tv-with-fubo-in-groundbreaking-deal/',)
# 200 - Updating author for article ('https://techcrunch.com/2025/01/06/lucid-meets-production-target-with-9029-ev-deliveries-in-2024/',)
# 201 - Updating author for article ('https://techcrunch.com/2025/01/06/bird-buddy-expands-into-insects-with-wonder-line/',)
# 202 - Updating author for article ('https://techcrunch.com/2025/01/06/intel-shows-off-its-latest-chip-lineup-at-ces-2025/',)
# 203 - Updating author for article ('https://techcrunch.com/2025/01/06/kiddes-new-smoke-detectors-have-ring-technology-built-in/',)
# 204 - Updating author for article ('https://techcrunch.com/2025/01/06/soliddd-is-building-smart-glasses-for-people-with-macular-degeneration/',)
# 205 - Updating author for article ('https://techcrunch.com/2025/01/06/avataar-releases-new-tool-to-create-ai-generated-videos-for-products/',)
# 206 - Updating author for article ('https://techcrunch.com/2025/01/06/samsungs-ces-2025-press-conference-how-to-watch/',)
# 207 - Updating author for article ('https://techcrunch.com/2025/01/06/elvie-unveils-an-app-controlled-smart-bouncer-that-transforms-into-a-bassinet-at-ces-2025/',)
# 208 - Updating author for article ('https://techcrunch.com/2025/01/06/amds-ces-2025-press-conference-how-to-watch/',)
# 209 - Updating author for article ('https://techcrunch.com/2025/01/05/openai-is-losing-money-on-its-pricey-chatgpt-pro-plan-ceo-sam-altman-says/',)
# 210 - Updating author for article ('https://techcrunch.com/2025/01/05/kirin-offers-a-taste-of-its-electric-salt-spoon-at-ces-2025/',)
# 211 - Updating author for article ('https://techcrunch.com/2025/01/05/samsung-brings-live-translate-to-its-tvs-at-ces-2025/',)
# 212 - Updating author for article ('https://techcrunch.com/2025/01/05/samsungs-new-tvs-can-find-recipes-for-dishes-in-shows/',)
# 213 - Updating author for article ('https://techcrunch.com/2025/01/05/withings-omnia-is-a-full-size-body-scanning-health-mirror/',)
# 214 - Updating author for article ('https://techcrunch.com/2025/01/05/openai-is-beginning-to-turn-its-attention-to-superintelligence/',)
# 215 - Updating author for article ('https://techcrunch.com/2025/01/05/this-fuzzy-purse-mounted-robot-is-designed-to-delight-bystanders/',)
# 216 - Updating author for article ('https://techcrunch.com/2025/01/05/timekettles-new-earbuds-offer-real-time-translation-on-calls/',)
# 217 - Updating author for article ('https://techcrunch.com/2025/01/05/circular-unveils-its-next-gen-ring-2-with-ecg-functionality-and-afib-detection-at-ces-2025/',)
# 218 - Updating author for article ('https://techcrunch.com/2025/01/05/this-tiny-robot-cat-will-blow-on-your-coffee-to-cool-it-off/',)
# 219 - Updating author for article ('https://techcrunch.com/2025/01/05/birdfy-sees-your-smart-bird-feeder-and-raises-you-a-smart-birdbath/',)
# 220 - Updating author for article ('https://techcrunch.com/2025/01/05/accel-can-raise-billions-for-india-its-sticking-to-650-million/',)
# 221 - Updating author for article ('https://techcrunch.com/2025/01/05/sam-altman-has-choice-words-for-the-openai-board-members-who-fired-him/',)
# 222 - Updating author for article ('https://techcrunch.com/2025/01/05/toyotas-ces-2025-press-conference-how-to-watch/',)
# 223 - Updating author for article ('https://techcrunch.com/2025/01/05/youtuber-legaleagle-sues-paypal-over-sleeping-leech-honey-extension/',)
# 224 - Updating author for article ('https://techcrunch.com/2025/01/05/roborocks-roomba-competitor-gets-a-robot-arm/',)
# 225 - Updating author for article ('https://techcrunch.com/2025/01/05/bad-news-for-adrian-dittman-elon-musk-truthers/',)
# 226 - Updating author for article ('https://techcrunch.com/2025/01/05/united-airlines-accelerates-its-starlink-rollout-with-first-commercial-flight-planned-for-spring/',)
# 227 - Updating author for article ('https://techcrunch.com/2025/01/04/from-forced-landings-to-stuffed-animal-heads-headhunter-peterson-conway-is-defense-techs-wildest-power-broker/',)
# 228 - Updating author for article ('https://techcrunch.com/2025/01/04/tenable-ceo-amit-yoran-dies/',)
# 229 - Updating author for article ('https://techcrunch.com/2025/01/04/lyft-will-credit-nyc-riders-for-congestion-fee-throughout-january/',)
# 230 - Updating author for article ('https://techcrunch.com/2025/01/04/what-will-this-year-bring-in-vc-we-asked-a-few-investors/',)
# 231 - Updating author for article ('https://techcrunch.com/2025/01/03/new-ship-new-year-spacex-to-deploy-model-starlink-satellites-on-next-starship-launch/',)
# 232 - Updating author for article ('https://techcrunch.com/2025/01/03/uber-ceo-dara-khosrowshahi-resigns-from-self-driving-truck-startup-auroras-board/',)
# 233 - Updating author for article ('https://techcrunch.com/2025/01/03/inside-the-wild-fall-and-last-minute-revival-of-bench-the-vc-backed-accounting-startup-that-imploded-over-the-holidays/',)
# 234 - Updating author for article ('https://techcrunch.com/2025/01/03/these-fintech-companies-are-hiring-in-2025-after-a-turbulent-year/',)
# 235 - Updating author for article ('https://techcrunch.com/2025/01/03/scout-motors-evs-will-have-satellite-connectivity/',)
# 236 - Updating author for article ('https://techcrunch.com/2025/01/03/chatgpt-everything-to-know-about-the-ai-chatbot/',)
# 237 - Updating author for article ('https://techcrunch.com/2025/01/03/generative-ai-funding-reached-new-heights-in-2024/',)
# 238 - Updating author for article ('https://techcrunch.com/2025/01/03/microsoft-to-spend-80-billion-in-fy25-on-data-centers-for-ai/',)
# 239 - Updating author for article ('https://techcrunch.com/2025/01/03/turo-ceo-attackers-had-clean-records-background-checks-wouldnt-have-stopped-them/',)
# 240 - Updating author for article ('https://techcrunch.com/2025/01/03/ftc-orders-ai-accessibility-startup-accessibe-to-pay-1m-for-misleading-advertising/',)
# 241 - Updating author for article ('https://techcrunch.com/2025/01/03/bench-saved-by-the-bell-and-other-last-minute-deals-that-closed-2024/',)
# 242 - Updating author for article ('https://techcrunch.com/2025/01/03/hydrogen-tax-credit-rules-give-startups-clarity-while-boosting-nuclear-and-carbon-capture/',)
# 243 - Updating author for article ('https://techcrunch.com/2025/01/03/venture-fund-founder-sues-paypal-alleging-racial-discrimination/',)
# 244 - Updating author for article ('https://techcrunch.com/2025/01/03/us-sanctions-chinese-cyber-firm-linked-to-flax-typhoon-hacks/',)
# 245 - Updating author for article ('https://techcrunch.com/2025/01/03/apple-tv-will-be-free-to-stream-this-weekend/',)
# 246 - Updating author for article ('https://techcrunch.com/2025/01/03/these-magsafe-earbuds-snap-on-to-the-back-of-an-iphone/',)
# 247 - Updating author for article ('https://techcrunch.com/2025/01/03/electra-found-a-cheap-clean-way-to-purify-iron-and-its-raising-257m-to-make-it-happen/',)
# 248 - Updating author for article ('https://techcrunch.com/2025/01/03/online-gift-card-store-exposed-hundreds-of-thousands-of-peoples-identity-documents/',)
# 249 - Updating author for article ('https://techcrunch.com/2025/01/03/rivian-wraps-2024-with-more-than-50000-evs-delivered/',)
# 250 - Updating author for article ('https://techcrunch.com/2025/01/03/hindustan-unilever-minimalist-acquisition/',)
# 251 - Updating author for article ('https://techcrunch.com/2025/01/02/cloudflares-vpn-app-among-half-dozen-pulled-from-indian-app-stores/',)
# 252 - Updating author for article ('https://techcrunch.com/2025/01/02/peter-thiel-backed-venture-debt-firm-tacora-raises-268-7m-for-new-fund/',)
# 253 - Updating author for article ('https://techcrunch.com/2025/01/02/kobold-used-ai-to-find-copper-now-investors-are-piling-in-to-the-tune-of-537m/',)
# 254 - Updating author for article ('https://techcrunch.com/2025/01/02/xais-next-gen-grok-model-didnt-arrive-on-time-adding-to-a-trend/',)
# 255 - Updating author for article ('https://techcrunch.com/2025/01/02/these-55-robotics-companies-are-hiring/',)
# 256 - Updating author for article ('https://techcrunch.com/2025/01/02/meta-policy-chief-nick-clegg-steps-down/',)
# 257 - Updating author for article ('https://techcrunch.com/2025/01/02/police-investigating-cybertruck-fire-outside-trump-hotel-in-vegas/',)
# 258 - Updating author for article ('https://techcrunch.com/2025/01/02/ces-2025-what-to-expect-from-the-years-first-and-biggest-tech-show/',)
# 259 - Updating author for article ('https://techcrunch.com/2025/01/02/spotifys-partner-program-for-podcast-hosts-is-now-available/',)
# 260 - Updating author for article ('https://techcrunch.com/2025/01/02/thomson-reuters-acquires-tax-automation-company-safesend-for-600m/',)
# 261 - Updating author for article ('https://techcrunch.com/2025/01/02/tesla-cybertruck-fails-to-boost-2024-sales-as-annual-deliveries-fall-for-first-time/',)
# 262 - Updating author for article ('https://techcrunch.com/2025/01/02/apheris-rethinks-the-ai-data-bottleneck-in-life-science-with-federated-computing/',)
# 263 - Updating author for article ('https://techcrunch.com/2025/01/02/2025-will-be-the-year-climate-tech-learns-to-love-ai/',)
# 264 - Updating author for article ('https://techcrunch.com/2025/01/02/telegram-rolls-out-third-party-account-verification-filters/',)
# 265 - Updating author for article ('https://techcrunch.com/2025/01/02/chinese-government-hackers-reportedly-targeted-us-treasurys-sanctions-office-during-december-cyberattack/',)
# 266 - Updating author for article ('https://techcrunch.com/2025/01/01/people-are-playing-a-new-doom-themed-captcha/',)
# 267 - Updating author for article ('https://techcrunch.com/2025/01/01/internal-spacex-documents-show-the-sweet-stock-deals-offered-to-investors-like-a16z-gigafund/',)
# 268 - Updating author for article ('https://techcrunch.com/2025/01/01/robinhood-already-a-comeback-stock-has-even-more-aggressive-plans-for-2025/',)
# 269 - Updating author for article ('https://techcrunch.com/2025/01/01/2024-the-year-silicon-valley-stifled-the-ai-doom-movement/',)
# 270 - Updating author for article ('https://techcrunch.com/2025/01/01/openai-failed-to-deliver-the-opt-out-tool-it-promised-by-2025/',)
# 271 - Updating author for article ('https://techcrunch.com/2025/01/01/accel-closes-650-million-for-new-india-fund/',)
# 272 - Updating author for article ('https://techcrunch.com/2025/01/09/comcast-and-other-tv-streamers-are-now-chasing-youtubes-ad-dollars-instead-of-the-other-way-around/',)
# 273 - Updating author for article ('https://techcrunch.com/2025/01/09/video-editing-app-captions-switches-to-a-freemium-model-to-boost-growth/',)
# 274 - Updating author for article ('https://techcrunch.com/2025/01/09/hackers-are-exploiting-a-new-ivanti-vpn-security-bug-to-hack-into-company-networks/',)
# 275 - Updating author for article ('https://techcrunch.com/2025/01/09/apple-might-be-working-on-a-new-invites-app/',)
# 276 - Updating author for article ('https://techcrunch.com/2025/01/08/xai-is-testing-a-standalone-ios-app-for-its-grok-chatbot/',)
# 277 - Updating author for article ('https://techcrunch.com/2025/01/08/ces-2025-was-full-of-irl-ai-slop/',)
# 278 - Updating author for article ('https://techcrunch.com/2025/01/08/ces-2025-the-weirdest-tech-products-and-claims-from-this-years-event/',)
# 279 - Updating author for article ('https://techcrunch.com/2025/01/08/astrohaus-launches-a-mechanical-keyboard-for-writers/',)
# 280 - Updating author for article ('https://techcrunch.com/2025/01/07/report-vc-in-emerging-markets-plummeted-by-over-40-last-year/',)
# 281 - Updating author for article ('https://techcrunch.com/2025/01/08/flock-safety-quietly-hired-a-sitting-california-mayor-now-hes-suing-flock/',)
# 282 - Updating author for article ('https://techcrunch.com/2025/01/08/tech-layoffs-2024-list/',)
# 283 - Updating author for article ('https://techcrunch.com/2025/01/08/former-huami-employees-launch-satellai-a-satellite-pet-tracker-at-ces-2025/',)
# 284 - Updating author for article ('https://techcrunch.com/2025/01/08/facebook-marketplace-to-display-ebay-listings-to-appease-eu-regulators/',)
# 285 - Updating author for article ('https://techcrunch.com/2025/01/08/steamos-expands-to-other-gaming-handhelds-with-the-lenovo-legion-go-s/',)
# 286 - Updating author for article ('https://techcrunch.com/2025/01/07/nomupay-raises-37m-on-a-200m-valuation-to-build-payment-rails-in-underserved-markets-across-asia/',)
# 287 - Updating author for article ('https://techcrunch.com/2025/01/07/nvidia-ceo-says-his-ai-chips-are-improving-faster-than-moores-law/',)
# 288 - Updating author for article ('https://techcrunch.com/2025/01/07/x-hires-former-wsj-editor-and-bureau-chief-to-lead-news-group/',)
# 289 - Updating author for article ('https://techcrunch.com/2025/01/11/apple-board-opposes-proposal-to-abolish-dei-programs/',)
# 290 - Updating author for article ('https://techcrunch.com/2025/01/09/powerschool-says-hackers-stole-students-sensitive-data-including-social-security-numbers-in-data-breach/',)
# 291 - Updating author for article ('https://techcrunch.com/2025/01/08/grok-may-soon-get-an-unhinged-mode/',)
# 292 - Updating author for article ('https://techcrunch.com/2025/01/07/this-pool-cleaning-company-made-a-robot-turtle-to-track-water-quality/',)

# %%
cursor.execute("SELECT * FROM pg_stat_activity WHERE state = 'active';")

# %%
for row in cursor:
    print(row)
# Out:
# (16384, 'techvector', 6847, None, 16385, 'stefan', '', '127.0.0.1', None, 54990, datetime.datetime(2025, 1, 13, 8, 0, 13, 749892, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), datetime.datetime(2025, 1, 13, 8, 0, 20, 957313, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), datetime.datetime(2025, 1, 13, 8, 0, 20, 959947, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), datetime.datetime(2025, 1, 13, 8, 0, 20, 959947, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), None, None, 'active', None, '1072', None, "SELECT * FROM pg_stat_activity WHERE state = 'active';", 'client backend')

# %%
cursor.execute("rollback;")

# %%
cursor.execute("SELECT pg_terminate_backend(13100);")

# %%
print(get_author("https://techcrunch.com/2025/01/11/i-got-soaked-driving-the-arc-sport-electric-boat/"))
# Out:
# Sean O’Kane
